# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# make array from text file test_accuracy.txt
test_acc = np.loadtxt('test_accuracy.txt')
acc = np.loadtxt('accuracy.txt')

# plot test accuracy
plt.plot(acc)
plt.plot(test_acc)
plt.xlabel('Epoch')
plt.ylabel('Test accuracy')
plt.show()

# %%
precision = np.loadtxt('test_precision.txt')
plt.ylim(0, 1)
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.show()
